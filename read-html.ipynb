# %%
from bs4 import BeautifulSoup

file = "/Users/joregan/Playing/librivox_mult/pg13028-images.html"

# %%
with open(file, "r") as f:
    soup = BeautifulSoup(f, "html.parser")

# %%
for element in soup.find_all("div", class_="pg_body_wrapper"):
    element.decompose()

# %%
from bs4 import Tag

pieces = []

for child in soup.children:
    if isinstance(child, Tag) and child.name in ["h3", "p"]:
        pieces.append((child.name, child.text.replace("\n", " ").strip()))

# %%
import nltk
for tag, text in pieces:
    sent_text = nltk.sent_tokenize(text)
    for sentence in sent_text:
        print(f"{tag}: {sentence}")

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 9.2 MB/s eta 0:00:01
# Requirement already satisfied: joblib in /Users/joregan/opt/anaconda3/envs/ctcseg/lib/python3.10/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/joregan/opt/anaconda3/envs/ctcseg/lib/python3.10/site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: click in /Users/joregan/opt/anaconda3/envs/ctcseg/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: tqdm in /Users/joregan/opt/anaconda3/envs/ctcseg/lib/python3.10/site-packages (from nltk) (4.64.0)
# Installing collected packages: nltk
# Successfully installed nltk-3.9.2
